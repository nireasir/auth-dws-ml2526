# %% [markdown]
# <a href="https://colab.research.google.com/github/nireasir/auth-dws-ml2526/blob/main/MLex8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Imports

# %%
import os
import PIL
import random
import matplotlib.pyplot as plt
import numpy as np
import pandas
import tensorflow as tf
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Ερώημα 2

# %%
# !unzip archive.zip

# %% [markdown]
# # Ερώτημα 3

# %%
class_names = sorted(os.listdir('dataset'))
class_ids = {label: i for i, label in enumerate(class_names)}
image_size = (64, 64)
inputs = []
targets = []
for label in class_names:
    for filename in os.listdir(f'dataset/{label}'):
        filepath = f'dataset/{label}/{filename}'
        img = PIL.Image.open(filepath).convert('RGB').resize(image_size)
        inputs.append(img)
        targets.append(class_ids[label])
inputs = np.float32(inputs)
targets = np.int32(targets)
num_classes = len(class_names)
targets_one_hot = np.eye(num_classes)[targets]
inputs.shape, targets_one_hot.shape
# Out:
# ((967, 64, 64, 3), (967, 10))

# %% [markdown]
# # Ερώτημα 4

# %%
seed = 0
tf.random.set_seed(seed=seed)
np.random.seed(seed=seed)
random.seed(seed)
x_train, x_test, y_train, y_test = train_test_split(
    inputs,
    targets_one_hot,
    test_size=0.3,
    stratify=targets,
    random_state=seed
)

# %%
input_size = x_train.shape[1:]
output_size = len(class_names)

mlp = tf.keras.Sequential([
    tf.keras.layers.Input(shape=input_size),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=128, activation='relu', use_bias=True),
    tf.keras.layers.Dense(units=128, activation='relu', use_bias=True),
    tf.keras.layers.Dense(units=output_size, activation='softmax', use_bias=True)
], name='MLP')
mlp.summary()
# Out:
# Model: "MLP"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 12288)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     1,572,992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,590,794 (6.07 MB)
#  Trainable params: 1,590,794 (6.07 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Ερώτημα 5

# %%
optim = tf.keras.optimizers.Adam(learning_rate=0.001)
mlp.compile(optimizer=optim, loss='categorical_crossentropy', metrics=['accuracy'])
batch_size = 32
epochs = 30
history = mlp.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(x_test, y_test)
)
# Out:
# Epoch 1/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - accuracy: 0.0998 - loss: 982.0352 - val_accuracy: 0.1031 - val_loss: 656.2186
# Epoch 2/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1525 - loss: 516.2398 - val_accuracy: 0.2234 - val_loss: 131.2924
# Epoch 3/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2498 - loss: 122.4482 - val_accuracy: 0.2440 - val_loss: 115.9007
# Epoch 4/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3388 - loss: 80.9011 - val_accuracy: 0.3299 - val_loss: 64.4725
# Epoch 5/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4590 - loss: 42.4099 - val_accuracy: 0.4158 - val_loss: 43.3184
# Epoch 6/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5448 - loss: 30.3344 - val_accuracy: 0.5326 - val_loss: 27.7375
# Epoch 7/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6338 - loss: 23.9102 - val_accuracy: 0.6289 - val_loss: 19.3540
# Epoch 8/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7097 - loss: 14.6295 - val_accuracy: 0.2921 - val_loss: 90.2302
# Epoch 9/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5066 - loss: 55.0885 - val_accuracy: 0.6014 - val_loss: 20.7745
# Epoch 10/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6152 - loss: 24.3340 - val_accuracy: 0.3471 - val_loss: 69.2917
# Epoch 11/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4724 - loss: 55.9231 - val_accuracy: 0.3608 - val_loss: 73.4343
# Epoch 12/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5525 - loss: 42.1249 - val_accuracy: 0.5120 - val_loss: 33.3079
# Epoch 13/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6708 - loss: 22.4456 - val_accuracy: 0.5258 - val_loss: 52.1245
# Epoch 14/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7068 - loss: 22.0234 - val_accuracy: 0.5979 - val_loss: 39.6935
# Epoch 15/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7451 - loss: 23.0020 - val_accuracy: 0.5739 - val_loss: 33.1481
# Epoch 16/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7383 - loss: 15.0701 - val_accuracy: 0.7113 - val_loss: 17.2872
# Epoch 17/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8506 - loss: 6.0258 - val_accuracy: 0.8385 - val_loss: 6.7617
# Epoch 18/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8973 - loss: 2.7146 - val_accuracy: 0.6048 - val_loss: 21.7248
# Epoch 19/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8287 - loss: 7.3582 - val_accuracy: 0.6907 - val_loss: 22.7026
# Epoch 20/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8536 - loss: 7.6010 - val_accuracy: 0.8419 - val_loss: 7.6422
# Epoch 21/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8847 - loss: 5.5055 - val_accuracy: 0.4880 - val_loss: 38.2609
# Epoch 22/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7824 - loss: 16.5689 - val_accuracy: 0.7698 - val_loss: 10.0420
# Epoch 23/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8797 - loss: 6.3423 - val_accuracy: 0.8591 - val_loss: 8.8132
# Epoch 24/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8778 - loss: 5.0601 - val_accuracy: 0.7560 - val_loss: 13.6153
# Epoch 25/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8616 - loss: 6.7584 - val_accuracy: 0.7388 - val_loss: 10.6612
# Epoch 26/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7996 - loss: 13.0698 - val_accuracy: 0.6254 - val_loss: 29.9699
# Epoch 27/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7613 - loss: 12.3901 - val_accuracy: 0.7113 - val_loss: 14.9531
# Epoch 28/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8455 - loss: 7.5066 - val_accuracy: 0.7388 - val_loss: 15.9584
# Epoch 29/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8486 - loss: 7.9035 - val_accuracy: 0.7457 - val_loss: 10.2728
# Epoch 30/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8342 - loss: 6.5549 - val_accuracy: 0.5155 - val_loss: 30.0176

# %% [markdown]
# # Ερώτημα 6

# %%
plt.figure()
plt.plot(history.history['loss'], label='Train loss')
plt.plot(history.history['val_loss'], label='Val loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

plt.figure()
plt.plot(history.history['accuracy'], label='Train accuracy')
plt.plot(history.history['val_accuracy'], label='Val accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training vs Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Ερώτημα 7

# %%
cnn = tf.keras.Sequential([
    tf.keras.layers.Input(shape=input_size),
    tf.keras.layers.Conv2D(filters=32, kernel_size=3, strides=2, activation='relu', use_bias=True),
    tf.keras.layers.Dropout(rate=0.2),
    tf.keras.layers.Conv2D(filters=32, kernel_size=3, strides=1, activation='relu', use_bias=True),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=128, activation='relu', use_bias=True),
    tf.keras.layers.Dense(units=output_size, activation='softmax', use_bias=True)
], name='CNN')
cnn.summary()
# Out:
# Model: "CNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 31, 31, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 31, 31, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 29, 29, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 26912)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 128)            │     3,444,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,456,298 (13.18 MB)
#  Trainable params: 3,456,298 (13.18 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
optim = tf.keras.optimizers.Adam(learning_rate=0.001)
cnn.compile(optimizer=optim, loss='categorical_crossentropy', metrics=['accuracy'])

history = cnn.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(x_test, y_test)
)
# Out:
# Epoch 1/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 8s 175ms/step - accuracy: 0.1250 - loss: 176.6729 - val_accuracy: 0.1478 - val_loss: 2.2683
# Epoch 2/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2498 - loss: 2.0619 - val_accuracy: 0.5739 - val_loss: 1.5613
# Epoch 3/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6234 - loss: 1.2248 - val_accuracy: 0.7801 - val_loss: 0.8763
# Epoch 4/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8548 - loss: 0.5421 - val_accuracy: 0.9175 - val_loss: 0.4160
# Epoch 5/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9508 - loss: 0.1916 - val_accuracy: 0.9759 - val_loss: 0.1643
# Epoch 6/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9760 - loss: 0.1026 - val_accuracy: 0.9588 - val_loss: 0.2952
# Epoch 7/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9560 - loss: 0.1821 - val_accuracy: 0.9897 - val_loss: 0.1869
# Epoch 8/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9908 - loss: 0.0591 - val_accuracy: 0.9897 - val_loss: 0.2312
# Epoch 9/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9772 - loss: 0.0618 - val_accuracy: 0.9863 - val_loss: 0.2096
# Epoch 10/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9881 - loss: 0.0585 - val_accuracy: 0.9897 - val_loss: 0.2644
# Epoch 11/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9935 - loss: 0.0187 - val_accuracy: 0.9897 - val_loss: 0.3171
# Epoch 12/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9854 - loss: 0.0427 - val_accuracy: 0.9897 - val_loss: 0.2289
# Epoch 13/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9970 - loss: 0.0088 - val_accuracy: 0.9897 - val_loss: 0.2589
# Epoch 14/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9960 - loss: 0.0140 - val_accuracy: 0.9897 - val_loss: 0.3001
# Epoch 15/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9962 - loss: 0.0236 - val_accuracy: 0.9897 - val_loss: 0.2843
# Epoch 16/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9996 - loss: 0.0045 - val_accuracy: 0.9897 - val_loss: 0.2814
# Epoch 17/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9984 - loss: 0.0045 - val_accuracy: 0.9897 - val_loss: 0.2808
# Epoch 18/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9897 - val_loss: 0.2791
# Epoch 19/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 9.9649e-04 - val_accuracy: 0.9897 - val_loss: 0.2794
# Epoch 20/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9956 - loss: 0.0314 - val_accuracy: 0.9897 - val_loss: 0.2497
# Epoch 21/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9980 - loss: 0.0043 - val_accuracy: 0.9897 - val_loss: 0.2638
# Epoch 22/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.9897 - val_loss: 0.3022
# Epoch 23/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9988 - loss: 0.0063 - val_accuracy: 0.9897 - val_loss: 0.2677
# Epoch 24/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9897 - val_loss: 0.2695
# Epoch 25/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.9897 - val_loss: 0.2786
# Epoch 26/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 3.7191e-04 - val_accuracy: 0.9897 - val_loss: 0.2800
# Epoch 27/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 3.2198e-04 - val_accuracy: 0.9897 - val_loss: 0.2720
# Epoch 28/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 1.8560e-04 - val_accuracy: 0.9897 - val_loss: 0.2678
# Epoch 29/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 6.8135e-04 - val_accuracy: 0.9897 - val_loss: 0.2715
# Epoch 30/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 1.7407e-04 - val_accuracy: 0.9897 - val_loss: 0.2715

# %%
plt.figure()
plt.plot(history.history['loss'], label='Train loss')
plt.plot(history.history['val_loss'], label='Val loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

plt.figure()
plt.plot(history.history['accuracy'], label='Train accuracy')
plt.plot(history.history['val_accuracy'], label='Val accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training vs Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Το μοντέλο CNN είναι καλύτερο διότι σύμφωνα με τα plots, η ακρίβεια του cnn στα train και validation set είναι πολύ υψηλότερη (σχεδόν 100%) από αυτή του MLP. Επιπλέον, το loss είναι σταθερά πολύ χαμηλό στο cnn (σχεδόν μηδενικό) και σχετικά χαμηλότερο από αυτό του mlp.
